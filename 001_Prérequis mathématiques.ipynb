# %% [markdown]
# # Prérequis mathématiques

# %% [markdown]
# #### Définir la valeur d'une variable

# %%
a = 10

# %% [markdown]
# #### Convertir en chaîne hexadécimale préfixée de 0x

# %%
hex(15)
# Out:
# '0xf'

# %% [markdown]
# #### Renvoyer le nombre entier selon Unicode

# %%
ord('3')
# Out:
# 51

# %% [markdown]
# #### Renvoyer le caractère selon Unicode

# %%
chr(98)
# Out:
# 'b'

# %% [markdown]
# #### Tracer les graphiques des fonctions
# $$f_1(x)=3x+5$$
#
# $$f_2(x)=\frac{x^3+x^2 +5x}{e^x}$$

# %%
# Afficher le résultat dans Jupyter, directement sous la cellule de code qui l'a produite
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
def simple_function(x):
    return 3 * x + 5

# %%
def some_complex_function(x):
    return (x ** 3 + x **2 + 5 * x) / (np.e ** x)

# %%
Xs = [_x for _x in range(-100, 100)]
Ys = [simple_function(_x) for _x in Xs]

# %%
_Xs = [_x for _x in range(0, 100)]
_Ys = [some_complex_function(_x) for _x in _Xs]

# %%
plt.plot(Xs, Ys)

# %%
plt.plot(_Xs, _Ys)

# %% [markdown]
# #### Calculer la dérivée
# $$f_3(x)=2x^2+3x+4$$
#
# $$f_4(x)=f'_3(x)$$

# %%
def square_f(x):
    return 2 * x**2 + 3 * x + 4

# %%
square_f(4)
# Out:
# 48

# %%
Xs = [_x for _x in range(-100, 100)]
Ys = [square_f(_x) for _x in Xs]

# %%
plt.plot(Xs, Ys)

# %%
def derivate(Xs, func, h=1e-4):
    return [(func(x+h) - func(x)) / h for x in Xs]

# %%
Xs = range(0, 75)
plt.plot(Xs, [square_f(_x) for _x in Xs])
plt.plot(range(0, 75), derivate(range(0, 75), square_f), color='r')

# %% [markdown]
# Tracer indépendamment la dérivée de la fonction $f_3(x)$

# %%
plt.plot(range(0, 75), derivate(range(0, 75), square_f), color='r')

# %% [markdown]
# Tracer la dérivée de la fonction $f_2(x)$

# %%
plt.plot(range(0, 75), derivate(range(0, 75), some_complex_function), color='r')

# %%
np.linspace(0, 10, 100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %% [markdown]
# #### Calculer l'intégrale

# %%
def approximate_area(xs, ys):
    
    area = 0
    
    for i, (x, y) in enumerate(zip(xs[1:], ys[1:])):
        sub_area = (x - xs[i]) * (ys[i] + y) / 2
        area += sub_area
    
    return area

# %%
Xs = np.linspace(0, 75, 100)
approximate_area(Xs, [simple_function(x) for x in Xs])
# Out:
# 8812.5

# %%
Xs = np.linspace(0, 75, 10)
approximate_area(Xs, [square_f(x) for x in Xs])
# Out:
# 291723.61111111107

# %% [markdown]
# Augmenter le degré de précision

# %%
Xs = np.linspace(0, 75, 1000)
approximate_area(Xs, [square_f(x) for x in Xs])
# Out:
# 289987.6409066723

# %%
Xs = np.linspace(0, 75, 100000)
approximate_area(Xs, [square_f(x) for x in Xs])
# Out:
# 289987.50001406315

# %% [markdown]
# Valider le résultat

# %% [markdown]
# $$f_3(x)=2x^2+3x+4$$
#
# $$F_3(x)=\frac{2}{3}x^3+\frac{3}{2}*x^2+4x$$

# %%
def original_f(x):
    return 2 * x**3 / 3 + 3 * x**2 / 2 + 4 * x

# %%
original_f(75)
# Out:
# 289987.5
